# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import pandas
import numpy as np
import pickle as pk
import sklearn as sk
# Out:
# 2023-05-27 01:25:15.349757: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-27 01:25:15.935788: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = pandas.read_csv("./../codes/semantic.csv")
data.dropna()
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2023-05-27 01:25:19.583125: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
x = data.iloc[0:, 0:32].values.astype("float64")
y = data.iloc[0:, 32].values.astype("bool")

# %%
tf.random.set_seed(120)
tf.keras.backend.clear_session()
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)
x_train_0 = np.array([x[0:16] for x in x_train])
x_train_1 = np.array([x[16:32] for x in x_train])
x_test_0 = np.array([x[0:16] for x in x_test])
x_test_1 = np.array([x[16:32] for x in x_test])

print(x_train_0.shape)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Concatenate
from tensorflow.keras import layers, Model, backend as K

def create_base_network(input_shape):
    input = layers.Input(shape=(input_shape,))
    x = layers.Dense(128, activation='relu')(input)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dense(64, activation='relu')(x)
    return Model(input, x)

def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))

def create_siamese_network(input_shape):
    # Define the tensors for the two input images
    input_1 = layers.Input(shape=(input_shape,))
    input_2 = layers.Input(shape=(input_shape,))

    # Create the base network
    base_network = create_base_network(input_shape)

    # Use the base network to process the inputs
    processed_1 = base_network(input_1)
    processed_2 = base_network(input_2)

    # Compute the Euclidean distance between the two vector outputs
    dist = layers.Lambda(euclidean_distance)([processed_1, processed_2])

    # Add a dense layer with a sigmoid unit to generate the similarity score
    outputs = layers.Dense(1, activation='sigmoid')(dist)

    # Instantiate the model
    siamese_net = Model([input_1, input_2], outputs)
    
    return siamese_net

model = create_siamese_network(16)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# (210140, 16)

# %%
history = model.fit([x_train_0,x_train_1], y_train,validation_data=([x_test_0,x_test_1],y_test), epochs=60)
# Out:
# Epoch 1/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.6381 - accuracy: 0.6279 - val_loss: 0.6264 - val_accuracy: 0.6459
# Epoch 2/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.6263 - accuracy: 0.6417 - val_loss: 0.6307 - val_accuracy: 0.6343
# Epoch 3/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.6213 - accuracy: 0.6489 - val_loss: 0.6188 - val_accuracy: 0.6506
# Epoch 4/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.6147 - accuracy: 0.6552 - val_loss: 0.6148 - val_accuracy: 0.6571
# Epoch 5/60
# 6567/6567 [==============================] - 6s 962us/step - loss: 0.6108 - accuracy: 0.6606 - val_loss: 0.6064 - val_accuracy: 0.6711
# Epoch 6/60
# 6567/6567 [==============================] - 6s 859us/step - loss: 0.6048 - accuracy: 0.6676 - val_loss: 0.6048 - val_accuracy: 0.6722
# Epoch 7/60
# 6567/6567 [==============================] - 6s 867us/step - loss: 0.5959 - accuracy: 0.6767 - val_loss: 0.5873 - val_accuracy: 0.6857
# Epoch 8/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.5834 - accuracy: 0.6889 - val_loss: 0.5811 - val_accuracy: 0.6956
# Epoch 9/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.5671 - accuracy: 0.7047 - val_loss: 0.5622 - val_accuracy: 0.7112
# Epoch 10/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.5470 - accuracy: 0.7248 - val_loss: 0.5303 - val_accuracy: 0.7383
# Epoch 11/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.5238 - accuracy: 0.7458 - val_loss: 0.5055 - val_accuracy: 0.7597
# Epoch 12/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.5001 - accuracy: 0.7652 - val_loss: 0.4849 - val_accuracy: 0.7799
# Epoch 13/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.4730 - accuracy: 0.7844 - val_loss: 0.4382 - val_accuracy: 0.8100
# Epoch 14/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.4414 - accuracy: 0.8052 - val_loss: 0.4186 - val_accuracy: 0.8182
# Epoch 15/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.4089 - accuracy: 0.8269 - val_loss: 0.3925 - val_accuracy: 0.8373
# Epoch 16/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.3764 - accuracy: 0.8478 - val_loss: 0.3494 - val_accuracy: 0.8642
# Epoch 17/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.3492 - accuracy: 0.8637 - val_loss: 0.3093 - val_accuracy: 0.8876
# Epoch 18/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.3271 - accuracy: 0.8754 - val_loss: 0.3136 - val_accuracy: 0.8816
# Epoch 19/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.3082 - accuracy: 0.8848 - val_loss: 0.2870 - val_accuracy: 0.8964
# Epoch 20/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.2965 - accuracy: 0.8910 - val_loss: 0.3036 - val_accuracy: 0.8883
# Epoch 21/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.2854 - accuracy: 0.8961 - val_loss: 0.2781 - val_accuracy: 0.9021
# Epoch 22/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2779 - accuracy: 0.9002 - val_loss: 0.2563 - val_accuracy: 0.9112
# Epoch 23/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2718 - accuracy: 0.9027 - val_loss: 0.2875 - val_accuracy: 0.8927
# Epoch 24/60
# 6567/6567 [==============================] - 9s 1ms/step - loss: 0.2661 - accuracy: 0.9054 - val_loss: 0.2404 - val_accuracy: 0.9190
# Epoch 25/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.2600 - accuracy: 0.9087 - val_loss: 0.2581 - val_accuracy: 0.9098
# Epoch 26/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.2523 - accuracy: 0.9122 - val_loss: 0.2320 - val_accuracy: 0.9251
# Epoch 27/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.2449 - accuracy: 0.9155 - val_loss: 0.2804 - val_accuracy: 0.8954
# Epoch 28/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.2408 - accuracy: 0.9176 - val_loss: 0.2246 - val_accuracy: 0.9265
# Epoch 29/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2329 - accuracy: 0.9209 - val_loss: 0.2247 - val_accuracy: 0.9272
# Epoch 30/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2275 - accuracy: 0.9228 - val_loss: 0.2078 - val_accuracy: 0.9286
# Epoch 31/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2227 - accuracy: 0.9241 - val_loss: 0.2253 - val_accuracy: 0.9220
# Epoch 32/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2170 - accuracy: 0.9255 - val_loss: 0.2304 - val_accuracy: 0.9193
# Epoch 33/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2102 - accuracy: 0.9275 - val_loss: 0.2394 - val_accuracy: 0.9104
# Epoch 34/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.2042 - accuracy: 0.9288 - val_loss: 0.2033 - val_accuracy: 0.9284
# Epoch 35/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1983 - accuracy: 0.9301 - val_loss: 0.2043 - val_accuracy: 0.9267
# Epoch 36/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1926 - accuracy: 0.9308 - val_loss: 0.2157 - val_accuracy: 0.9186
# Epoch 37/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1874 - accuracy: 0.9323 - val_loss: 0.1941 - val_accuracy: 0.9330
# Epoch 38/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1790 - accuracy: 0.9348 - val_loss: 0.1734 - val_accuracy: 0.9370
# Epoch 39/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1721 - accuracy: 0.9369 - val_loss: 0.1498 - val_accuracy: 0.9437
# Epoch 40/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1623 - accuracy: 0.9399 - val_loss: 0.1646 - val_accuracy: 0.9405
# Epoch 41/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1556 - accuracy: 0.9424 - val_loss: 0.1418 - val_accuracy: 0.9471
# Epoch 42/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1453 - accuracy: 0.9463 - val_loss: 0.1345 - val_accuracy: 0.9489
# Epoch 43/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1372 - accuracy: 0.9491 - val_loss: 0.1669 - val_accuracy: 0.9382
# Epoch 44/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1293 - accuracy: 0.9526 - val_loss: 0.1404 - val_accuracy: 0.9474
# Epoch 45/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1193 - accuracy: 0.9566 - val_loss: 0.1034 - val_accuracy: 0.9632
# Epoch 46/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1133 - accuracy: 0.9587 - val_loss: 0.0990 - val_accuracy: 0.9621
# Epoch 47/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.1020 - accuracy: 0.9630 - val_loss: 0.0990 - val_accuracy: 0.9646
# Epoch 48/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0937 - accuracy: 0.9663 - val_loss: 0.0917 - val_accuracy: 0.9670
# Epoch 49/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0874 - accuracy: 0.9687 - val_loss: 0.1029 - val_accuracy: 0.9601
# Epoch 50/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0787 - accuracy: 0.9720 - val_loss: 0.0721 - val_accuracy: 0.9748
# Epoch 51/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0720 - accuracy: 0.9744 - val_loss: 0.0629 - val_accuracy: 0.9780
# Epoch 52/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0659 - accuracy: 0.9766 - val_loss: 0.0779 - val_accuracy: 0.9727
# Epoch 53/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0597 - accuracy: 0.9788 - val_loss: 0.0534 - val_accuracy: 0.9807
# Epoch 54/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0576 - accuracy: 0.9804 - val_loss: 0.0659 - val_accuracy: 0.9751
# Epoch 55/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0543 - accuracy: 0.9817 - val_loss: 0.0487 - val_accuracy: 0.9815
# Epoch 56/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0496 - accuracy: 0.9830 - val_loss: 0.0432 - val_accuracy: 0.9848
# Epoch 57/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0472 - accuracy: 0.9839 - val_loss: 0.0334 - val_accuracy: 0.9899
# Epoch 58/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0439 - accuracy: 0.9850 - val_loss: 0.0432 - val_accuracy: 0.9850
# Epoch 59/60
# 6567/6567 [==============================] - 7s 1ms/step - loss: 0.0417 - accuracy: 0.9862 - val_loss: 0.0506 - val_accuracy: 0.9838
# Epoch 60/60
# 6567/6567 [==============================] - 8s 1ms/step - loss: 0.0387 - accuracy: 0.9871 - val_loss: 0.0190 - val_accuracy: 0.9950

# %%
y_pred = model.evaluate([x_test_0,x_test_1],y_test)
# Out:
# 2815/2815 [==============================] - 1s 522us/step - loss: 0.0190 - accuracy: 0.9950

# %%
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt

# Assuming that 'model' is your trained model and 'X_test', 'y_test' are your test data.

# Predict the probabilities for the test data
y_pred_prob = model.predict([x_test_0,x_test_1]).ravel()

# Predict the classes for the test data
y_pred = np.round(y_pred_prob)

# Print precision, recall, and F1-score
print(classification_report(y_test, y_pred))

# Calculate AUC-ROC
roc_auc = roc_auc_score(y_test, y_pred_prob)
print("AUC-ROC:", roc_auc)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.figure()
lw = 2  # Line width
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 2815/2815 [==============================] - 1s 437us/step
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99     44922
#         True       0.99      1.00      0.99     45138
#
#     accuracy                           0.99     90060
#    macro avg       0.99      0.99      0.99     90060
# weighted avg       0.99      0.99      0.99     90060
#
# AUC-ROC: 0.9998115357160184

# %%
import matplotlib.pyplot as plt

# Assuming that 'model' is your trained model, and 'history' is the returned History object from model.fit
# e.g., history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=20)

# Plot training & validation accuracy values
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
history.history
# Out:
# {'loss': [0.6381441950798035,
#   0.6262973546981812,
#   0.6213011145591736,
#   0.6146948933601379,
#   0.6107722520828247,
#   0.6047720313072205,
#   0.5959269404411316,
#   0.583428144454956,
#   0.5670763850212097,
#   0.5469594597816467,
#   0.5238144993782043,
#   0.500100314617157,
#   0.47295066714286804,
#   0.4414101839065552,
#   0.40887948870658875,
#   0.37638840079307556,
#   0.349214106798172,
#   0.3270570635795593,
#   0.30824410915374756,
#   0.296542227268219,
#   0.28542548418045044,
#   0.2778681516647339,
#   0.2718068063259125,
#   0.2661340832710266,
#   0.26000985503196716,
#   0.25225377082824707,
#   0.24492190778255463,
#   0.24077941477298737,
#   0.23286226391792297,
#   0.22754205763339996,
#   0.22272339463233948,
#   0.21696743369102478,
#   0.21016542613506317,
#   0.20421873033046722,
#   0.19825705885887146,
#   0.19264696538448334,
#   0.18743623793125153,
#   0.17900751531124115,
#   0.17207403481006622,
#   0.16228634119033813,
#   0.1555940806865692,
#   0.14530788362026215,
#   0.13720910251140594,
#   0.12931989133358002,
#   0.11934149265289307,
#   0.11330533772706985,
#   0.10195490717887878,
#   0.09370197355747223,
#   0.08744056522846222,
#   0.07872901856899261,
#   0.0719822570681572,
#   0.06590241193771362,
#   0.059703998267650604,
#   0.057575322687625885,
#   0.05430492013692856,
#   0.049614354968070984,
#   0.04715712368488312,
#   0.04385846108198166,
#   0.0417056605219841,
#   0.03868129104375839],
#  'accuracy': [0.6279099583625793,
#   0.6417340636253357,
#   0.6489102244377136,
#   0.6552298665046692,
#   0.6605929136276245,
#   0.6675644516944885,
#   0.6767202615737915,
#   0.688945472240448,
#   0.7046921253204346,
#   0.724793016910553,
#   0.7458456158638,
#   0.7651708126068115,
#   0.7844341993331909,
#   0.8052012920379639,
#   0.8268535137176514,
#   0.8478443026542664,
#   0.863657534122467,
#   0.8753735423088074,
#   0.8847768306732178,
#   0.8910012245178223,
#   0.8960597515106201,
#   0.9002189040184021,
#   0.9026601314544678,
#   0.9054011702537537,
#   0.9086846709251404,
#   0.9122251868247986,
#   0.9155086874961853,
#   0.9175549745559692,
#   0.9208717942237854,
#   0.9227562546730042,
#   0.9240696430206299,
#   0.92549729347229,
#   0.9274531006813049,
#   0.9287617802619934,
#   0.9300942420959473,
#   0.9308318495750427,
#   0.9322832226753235,
#   0.9348339438438416,
#   0.9368801712989807,
#   0.939868688583374,
#   0.9424098134040833,
#   0.9463452696800232,
#   0.9490958452224731,
#   0.9526220560073853,
#   0.9565528035163879,
#   0.9587132334709167,
#   0.9629722833633423,
#   0.9662986397743225,
#   0.968668520450592,
#   0.9719663262367249,
#   0.9744455814361572,
#   0.9765727519989014,
#   0.9788474440574646,
#   0.980355978012085,
#   0.9817454814910889,
#   0.9829827547073364,
#   0.983877420425415,
#   0.9850195050239563,
#   0.9861806631088257,
#   0.9870752692222595],
#  'val_loss': [0.6264355182647705,
#   0.6306790113449097,
#   0.6188067197799683,
#   0.6147953271865845,
#   0.6064172983169556,
#   0.6047766804695129,
#   0.5872759222984314,
#   0.5811039209365845,
#   0.5621747970581055,
#   0.530269205570221,
#   0.5054689049720764,
#   0.4849310517311096,
#   0.43815189599990845,
#   0.4186144173145294,
#   0.392510324716568,
#   0.3493969440460205,
#   0.3093409836292267,
#   0.31359297037124634,
#   0.28701481223106384,
#   0.30364716053009033,
#   0.2780879735946655,
#   0.2563495337963104,
#   0.2875070571899414,
#   0.24044273793697357,
#   0.2581159770488739,
#   0.23201963305473328,
#   0.28042277693748474,
#   0.22459135949611664,
#   0.22465157508850098,
#   0.20777608454227448,
#   0.22533269226551056,
#   0.2304302304983139,
#   0.23942305147647858,
#   0.2032749056816101,
#   0.20426218211650848,
#   0.21574924886226654,
#   0.194102481007576,
#   0.17335647344589233,
#   0.14977510273456573,
#   0.16462533175945282,
#   0.14182525873184204,
#   0.13452503085136414,
#   0.16688905656337738,
#   0.1403888314962387,
#   0.10342758893966675,
#   0.09899306297302246,
#   0.09898367524147034,
#   0.09174147248268127,
#   0.10290718823671341,
#   0.07209046930074692,
#   0.0628892183303833,
#   0.07790467143058777,
#   0.05338340997695923,
#   0.0659308210015297,
#   0.048711102455854416,
#   0.04319866746664047,
#   0.033435720950365067,
#   0.04318835586309433,
#   0.05063494294881821,
#   0.018970035016536713],
#  'val_accuracy': [0.6458582878112793,
#   0.6343437433242798,
#   0.6505773663520813,
#   0.6571285724639893,
#   0.6710637211799622,
#   0.6722296476364136,
#   0.6856984496116638,
#   0.6955807209014893,
#   0.7112036347389221,
#   0.7382744550704956,
#   0.759715735912323,
#   0.7799022793769836,
#   0.8100266456604004,
#   0.8182322978973389,
#   0.8373417854309082,
#   0.8641905188560486,
#   0.8875860571861267,
#   0.8816011548042297,
#   0.8964024186134338,
#   0.8882522583007812,
#   0.9020985960960388,
#   0.9112147688865662,
#   0.8927270770072937,
#   0.9189873337745667,
#   0.9098489880561829,
#   0.9250943660736084,
#   0.8953697681427002,
#   0.9264712333679199,
#   0.9272040724754333,
#   0.9286253452301025,
#   0.9220186471939087,
#   0.9193426370620728,
#   0.9104263782501221,
#   0.9284365773200989,
#   0.9267377257347107,
#   0.9186431169509888,
#   0.9330335259437561,
#   0.9369864463806152,
#   0.9437264204025269,
#   0.9405174255371094,
#   0.9471463561058044,
#   0.9488562941551208,
#   0.9381967782974243,
#   0.9474239349365234,
#   0.96323561668396,
#   0.9620919227600098,
#   0.9646347165107727,
#   0.9670220017433167,
#   0.9600599408149719,
#   0.9747834801673889,
#   0.9780479669570923,
#   0.9727070927619934,
#   0.9807128310203552,
#   0.9750943779945374,
#   0.9815012216567993,
#   0.9848323464393616,
#   0.9899400472640991,
#   0.9850432872772217,
#   0.9837552905082703,
#   0.9949589371681213]}
