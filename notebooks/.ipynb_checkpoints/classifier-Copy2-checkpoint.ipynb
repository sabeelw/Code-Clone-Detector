# %%
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import pandas as pd
import os
import numpy as np
import pickle as pk
import sklearn as sk
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
from sklearn.utils import shuffle
# Out:
# 2023-05-27 00:39:35.945227: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-27 00:39:36.568791: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = pd.read_csv("./../codes/semantic.csv")

shuffle(data)
data.dropna()
data.head()
print( tf.config.list_physical_devices())
data.shape
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# 2023-05-27 00:39:38.890067: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (300200, 33)

# %%
tf.random.set_seed(12)
tf.keras.backend.clear_session()
x = data.iloc[0:, 0:32].values.astype("float64").reshape(-1,2,16,1)
y = data.iloc[0:, 32].values.astype("float64")

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42,
                                                    shuffle=True)

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu',input_shape=(2,16)),
    Flatten(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              loss=tf.keras.losses.binary_crossentropy,
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=60)
# Out:
# Epoch 1/60
# 6567/6567 [==============================] - 4s 541us/step - loss: 0.6336 - accuracy: 0.6380
# Epoch 2/60
# 5835/6567 [=========================>....] - ETA: 0s - loss: 0.6334 - accuracy: 0.6393
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 history = model.fit(x_train, y_train, epochs=60)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1676, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1674 callbacks.on_epoch_begin(epoch)
#    1675 with data_handler.catch_stop_iteration():
# -> 1676     for step in data_handler.steps():
#    1677         with tf.profiler.experimental.Trace(
#    1678             "train",
#    1679             epoch_num=epoch,
#    (...)
#    1682             _r=1,
#    1683         ):
#    1684             callbacks.on_train_batch_begin(step)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras/engine/data_adapter.py:1375, in DataHandler.steps(self)
#    1373 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1374     break
# -> 1375 original_spe = self._steps_per_execution.numpy().item()
#    1376 can_run_full_execution = (
#    1377     original_spe == 1
#    1378     or self._inferred_steps is None
#    1379     or self._inferred_steps - self._current_step >= original_spe
#    1380 )
#    1382 if can_run_full_execution:
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:647, in BaseResourceVariable.numpy(self)
#     645 def numpy(self):
#     646   if context.executing_eagerly():
# --> 647     return self.read_value().numpy()
#     648   raise NotImplementedError(
#     649       "numpy() is only available when eager execution is enabled.")
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:774, in BaseResourceVariable.read_value(self)
#     765 """Constructs an op which reads the value of this variable.
#     766
#     767 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     771   The value of the variable.
#     772 """
#     773 with ops.name_scope("Read"):
# --> 774   value = self._read_variable_op()
#     775 # Return an identity so it can get placed on whatever device the context
#     776 # specifies instead of the device where the variable is.
#     777 return array_ops.identity(value)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:753, in BaseResourceVariable._read_variable_op(self, no_copy)
#     751       result = read_and_set_handle(no_copy)
#     752 else:
# --> 753   result = read_and_set_handle(no_copy)
#     755 if not context.executing_eagerly():
#     756   # Note that if a control flow context is active the input of the read op
#     757   # might not actually be the handle. This line bypasses it.
#     758   tape.record_operation(
#     759       "ReadVariableOp", [result], [self.handle],
#     760       backward_function=lambda x: [x],
#     761       forward_function=lambda x: [x])
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:743, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     741 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     742   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 743 result = gen_resource_variable_ops.read_variable_op(
#     744     self.handle, self._dtype)
#     745 _maybe_set_handle_data(self._dtype, self.handle, result)
#     746 return result
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:524, in read_variable_op(resource, dtype, name)
#     522 if tld.is_eager:
#     523   try:
# --> 524     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526     return _result
#     527   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
y_pred = model.evaluate(x_test,y_test)
# Out:
# 2815/2815 [==============================] - 1s 440us/step - loss: 0.3710 - accuracy: 0.8414

# %%
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt

# Assuming that 'model' is your trained model and 'X_test', 'y_test' are your test data.

# Predict the probabilities for the test data
y_pred_prob = model.predict(x_test).ravel()

# Predict the classes for the test data
y_pred = np.round(y_pred_prob)

# Print precision, recall, and F1-score
print(classification_report(y_test, y_pred))

# Calculate AUC-ROC
roc_auc = roc_auc_score(y_test, y_pred_prob)
print("AUC-ROC:", roc_auc)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.figure()
lw = 2  # Line width
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 2815/2815 [==============================] - 1s 420us/step
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84     45063
#          1.0       0.84      0.85      0.84     44997
#
#     accuracy                           0.84     90060
#    macro avg       0.84      0.84      0.84     90060
# weighted avg       0.84      0.84      0.84     90060
#
# AUC-ROC: 0.9183007757848037

# %%
import matplotlib.pyplot as plt

# Assuming that 'model' is your trained model, and 'history' is the returned History object from model.fit
# e.g., history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=20)

# Plot training & validation accuracy values
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
history.history
# Out:
# {'loss': [0.15337081253528595,
#   0.07224221527576447,
#   0.07113692909479141,
#   0.07045413553714752,
#   0.07000049948692322,
#   0.06967741250991821,
#   0.06943444907665253,
#   0.06923631578683853,
#   0.06907104700803757,
#   0.06892284750938416,
#   0.0688028410077095,
#   0.0686880573630333,
#   0.06858121603727341,
#   0.06849567592144012,
#   0.06840971112251282,
#   0.06833213567733765,
#   0.06826114654541016,
#   0.06819695234298706,
#   0.0681348592042923,
#   0.06807922571897507,
#   0.06802646070718765,
#   0.06797405332326889,
#   0.0679304301738739,
#   0.06788402795791626,
#   0.06784418970346451,
#   0.06780389696359634,
#   0.06776421517133713,
#   0.06772874295711517,
#   0.0676950141787529,
#   0.06766075640916824,
#   0.06762964278459549,
#   0.06760185956954956,
#   0.06757160276174545,
#   0.06754551827907562,
#   0.06751775741577148,
#   0.0674935057759285,
#   0.0674683153629303,
#   0.06744328886270523,
#   0.06742328405380249,
#   0.0674000009894371],
#  'accuracy': [0.9859197735786438,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874246716499329,
#   0.9874273538589478,
#   0.9874273538589478,
#   0.9874273538589478,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626,
#   0.9874300360679626],
#  'val_loss': [0.0735556036233902,
#   0.07157036662101746,
#   0.07066027075052261,
#   0.07001671195030212,
#   0.06960244476795197,
#   0.0692971721291542,
#   0.06906836479902267,
#   0.06888815015554428,
#   0.06872211396694183,
#   0.06859846413135529,
#   0.06847446411848068,
#   0.06837192922830582,
#   0.06829215586185455,
#   0.06819774955511093,
#   0.06812489032745361,
#   0.06806221604347229,
#   0.06799651682376862,
#   0.06794073432683945,
#   0.06789692491292953,
#   0.06784281134605408,
#   0.06779759377241135,
#   0.06775370985269547,
#   0.06771235167980194,
#   0.06767603754997253,
#   0.0676366537809372,
#   0.06760279089212418,
#   0.06757105141878128,
#   0.06754205375909805,
#   0.06751042604446411,
#   0.0674816220998764,
#   0.06745762377977371,
#   0.06742999702692032,
#   0.06740456074476242,
#   0.06738027185201645,
#   0.06735832989215851,
#   0.0673370361328125,
#   0.06731417775154114,
#   0.0672941580414772,
#   0.06727403402328491,
#   0.06725664436817169],
#  'val_accuracy': [0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648,
#   0.9874944686889648]}
